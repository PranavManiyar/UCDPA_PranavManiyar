# %%
Assignment: Pranav Maniyar

Real World Scenarios

# %%
#import required modules
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import seaborn as sns
import requests
from bs4 import BeautifulSoup as bs

# %%
df_house=pd.read_csv('UK-HPI-full-file-2022-07.csv')
df_house
# Out:
#               Date                RegionName   AreaCode  AveragePrice  \
# 0       01/01/2004             Aberdeenshire  S12000034   81693.66964
# 1       01/02/2004             Aberdeenshire  S12000034   81678.76231
# 2       01/03/2004             Aberdeenshire  S12000034   83525.09702
# 3       01/04/2004             Aberdeenshire  S12000034   84333.67900
# 4       01/05/2004             Aberdeenshire  S12000034   86379.95396
# ...            ...                       ...        ...           ...
# 137771  01/03/2022  Yorkshire and The Humber  E12000003  196887.00370
# 137772  01/04/2022  Yorkshire and The Humber  E12000003  199389.28479
# 137773  01/05/2022  Yorkshire and The Humber  E12000003  204076.87702
# 137774  01/06/2022  Yorkshire and The Humber  E12000003  205647.53948
# 137775  01/07/2022  Yorkshire and The Humber  E12000003  211960.15107
#
#              Index     IndexSA  1m%Change  12m%Change  AveragePriceSA  \
# ...

# %%
df_house.head(10)
# Out:
#          Date     RegionName   AreaCode  AveragePrice      Index  IndexSA  \
# 0  01/01/2004  Aberdeenshire  S12000034   81693.66964  40.864214      NaN
# 1  01/02/2004  Aberdeenshire  S12000034   81678.76231  40.856757      NaN
# 2  01/03/2004  Aberdeenshire  S12000034   83525.09702  41.780317      NaN
# 3  01/04/2004  Aberdeenshire  S12000034   84333.67900  42.184780      NaN
# 4  01/05/2004  Aberdeenshire  S12000034   86379.95396  43.208353      NaN
# 5  01/06/2004  Aberdeenshire  S12000034   89267.61305  44.652797      NaN
# 6  01/07/2004  Aberdeenshire  S12000034   93047.50105  46.543545      NaN
# 7  01/08/2004  Aberdeenshire  S12000034   97790.66757  48.916137      NaN
# 8  01/09/2004  Aberdeenshire  S12000034   98663.95545  49.352967      NaN
# 9  01/10/2004  Aberdeenshire  S12000034   99083.88349  49.563020      NaN
#
#    1m%Change  12m%Change  AveragePriceSA  SalesVolume  ...      NewPrice  \
# 0        NaN         NaN             NaN        388.0  ...   88436.13953
# ...

# %%
df_house.tail(10)
# Out:
#               Date                RegionName   AreaCode  AveragePrice  \
# 137766  01/10/2021  Yorkshire and The Humber  E12000003  186882.41918
# 137767  01/11/2021  Yorkshire and The Humber  E12000003  191897.01682
# 137768  01/12/2021  Yorkshire and The Humber  E12000003  193480.81558
# 137769  01/01/2022  Yorkshire and The Humber  E12000003  194702.92503
# 137770  01/02/2022  Yorkshire and The Humber  E12000003  197205.14925
# 137771  01/03/2022  Yorkshire and The Humber  E12000003  196887.00370
# 137772  01/04/2022  Yorkshire and The Humber  E12000003  199389.28479
# 137773  01/05/2022  Yorkshire and The Humber  E12000003  204076.87702
# 137774  01/06/2022  Yorkshire and The Humber  E12000003  205647.53948
# 137775  01/07/2022  Yorkshire and The Humber  E12000003  211960.15107
#
#              Index     IndexSA  1m%Change  12m%Change  AveragePriceSA  \
# 137766  137.243297  134.999734  -4.720314    7.182059    183827.38972
# ...

# %%
df_house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137776 entries, 0 to 137775
# Data columns (total 54 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Date                    137776 non-null  object
#  1   RegionName              137776 non-null  object
#  2   AreaCode                137776 non-null  object
#  3   AveragePrice            137776 non-null  float64
#  4   Index                   137776 non-null  float64
#  5   IndexSA                 4629 non-null    float64
#  6   1m%Change               137333 non-null  float64
#  7   12m%Change              132736 non-null  float64
#  8   AveragePriceSA          4629 non-null    float64
#  9   SalesVolume             133277 non-null  float64
#  10  DetachedPrice           131455 non-null  float64
#  11  DetachedIndex           131455 non-null  float64
#  12  Detached1m%Change       131046 non-null  float64
# ...

# %%
df_house_clean = pd.DataFrame(df_house,  columns=['Date','RegionName','AveragePrice','AveragePriceSA','SalesVolume ','DetachedPrice',
                                                 'Detached12m%Change','SemiDetachedPrice','SemiDetached12m%Change','TerracedPrice','Terraced12m%Change',
                                                 'FlatPrice','Flat12m%Change','CashPrice','Cash12m%Change','CashSalesVolume','MortgagePrice','MortgageSalesVolume',
                                                 ])

# %%
df_house_clean['Date'] = pd.to_datetime(df_house_clean['Date'], format='%d/%m/%Y')

# %%
df_house_clean.head(5)
# Out:
#         Date     RegionName  AveragePrice  AveragePriceSA  SalesVolume   \
# 0 2004-01-01  Aberdeenshire   81693.66964             NaN           NaN
# 1 2004-02-01  Aberdeenshire   81678.76231             NaN           NaN
# 2 2004-03-01  Aberdeenshire   83525.09702             NaN           NaN
# 3 2004-04-01  Aberdeenshire   84333.67900             NaN           NaN
# 4 2004-05-01  Aberdeenshire   86379.95396             NaN           NaN
#
#    DetachedPrice  Detached12m%Change  SemiDetachedPrice  \
# 0    122490.0641                 NaN        70563.15784
# 1    121280.8840                 NaN        70804.42408
# 2    123395.4269                 NaN        72689.07253
# 3    122334.0258                 NaN        74484.23119
# 4    124498.8747                 NaN        76637.73414
#
#    SemiDetached12m%Change  TerracedPrice  Terraced12m%Change    FlatPrice  \
# 0                     NaN    55319.63336                 NaN  48016.07412
# ...

# %%
df_house_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137776 entries, 0 to 137775
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Date                    137776 non-null  datetime64[ns]
#  1   RegionName              137776 non-null  object
#  2   AveragePrice            137776 non-null  float64
#  3   AveragePriceSA          4629 non-null    float64
#  4   SalesVolume             0 non-null       float64
#  5   DetachedPrice           131455 non-null  float64
#  6   Detached12m%Change      126571 non-null  float64
#  7   SemiDetachedPrice       131467 non-null  float64
#  8   SemiDetached12m%Change  126583 non-null  float64
#  9   TerracedPrice           131494 non-null  float64
#  10  Terraced12m%Change      126610 non-null  float64
#  11  FlatPrice               131798 non-null  float64
#  12  Flat12m%Change          126902 non-null  float64
# ...

# %%
import datetime 

df_house_clean[df_house_clean['Date'].item().datetime.year==2005]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22872/1767450130.py in <module>
#       1 import datetime
#       2
# ----> 3 df_house_clean[df_house_clean['Date'].item().datetime.year==2005]
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in item(self)
#     329         if len(self) == 1:
#     330             return next(iter(self))
# --> 331         raise ValueError("can only convert an array of size 1 to a Python scalar")
#     332
#     333     @property
#
# ValueError: can only convert an array of size 1 to a Python scalar

# %%
df_house_clean[(df_house_clean['Date'] >= '2005-01-01')]
# Out:
#              Date                RegionName  AveragePrice  AveragePriceSA  \
# 12     2005-01-01             Aberdeenshire  101818.93310             NaN
# 13     2005-02-01             Aberdeenshire   97626.00076             NaN
# 14     2005-03-01             Aberdeenshire   94779.34241             NaN
# 15     2005-04-01             Aberdeenshire   95847.70590             NaN
# 16     2005-05-01             Aberdeenshire  101744.46620             NaN
# ...           ...                       ...           ...             ...
# 137771 2022-03-01  Yorkshire and The Humber  196887.00370    195239.83920
# 137772 2022-04-01  Yorkshire and The Humber  199389.28479    196706.40443
# 137773 2022-05-01  Yorkshire and The Humber  204076.87702    201041.81756
# 137774 2022-06-01  Yorkshire and The Humber  205647.53948    201630.50399
# 137775 2022-07-01  Yorkshire and The Humber  211960.15107    207080.93940
#
#         SalesVolume   DetachedPrice  Detached12m%Change  SemiDetachedPrice  \
# ...

# %%
# This Wiki sourced dataset is being used to validate the information in the other dataset.
url = 'https://www.doogal.co.uk/PostcodeDistricts'
raw_data=[] # stores rows info
 
condition=True

while condition:
    
    page = requests.get(url)

    #creating soup object
    soup=bs(page.text,'lxml')

    table_body=soup.find('table')

    for row in table_body.find_all('tr'):
        col=row.find_all('td')
        col=[ele.text.strip() for ele in col]
        raw_data.append(col)
    
    #next page
    
    pg=soup.find('ul','pager')
    active_pg=pg.find('li','next')
    next_url=active_pg.findNextSibling('li').a.get('href')
    
   #test whether is blank
    
    if next_url == "":
     condition=False
    
    else:
        url=next_url
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22872/2332615185.py in <module>
#      22
#      23     pg=soup.find('ul','pager')
# ---> 24     active_pg=url.pg.find('li','next')
#      25     next_url=active_pg.findNextSibling('li').a.get('href')
#      26
#
# AttributeError: 'str' object has no attribute 'pg'

# %%
df_Postcodes[0].describe()
# Out:
#          Postcodes  Active postcodes  Population (2011)  Households (2011)
# count   200.000000        192.000000         185.000000         185.000000
# mean    907.410000        606.520833       23260.854054        9434.394595
# std     585.836499        351.629296       13734.133777        5487.643586
# min       1.000000          1.000000           9.000000           2.000000
# 25%     514.750000        356.750000       11495.000000        5139.000000
# 50%     862.000000        581.000000       23335.000000        9700.000000
# 75%    1128.750000        783.500000       32012.000000       12602.000000
# max    3070.000000       2189.000000       73927.000000       29525.000000

# %%
d=r.json()
print(d)
# Out:
# []

# %%
df.head(5)

# %%
import requests

url = "https://uk-property-data.p.rapidapi.com/propertytools.api.v1.Public/GetPropertyReport"

payload = {
	"postcode": "SL2 2AY",
	"paon": "25"
}
headers = {
	"content-type": "application/json",
	"X-RapidAPI-Key": "a305c7cb80msh6d7e3682921989dp169d9djsn4c7e5955773b",
	"X-RapidAPI-Host": "uk-property-data.p.rapidapi.com"
}

response = requests.request("POST", url, json=payload, headers=headers)

print(response.text)
# Out:
# {"message":"You are not subscribed to this API."}

# %%
https://use-land-property-data.service.gov.uk/api/v1/{endpoint}

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://api.zoopla.co.uk/api/v1/average_area_sold_price'
r = requests.get(url)
d= r.json()

print(d)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22872/1654867233.py in <module>
#       4 url = 'https://api.zoopla.co.uk/api/v1/average_area_sold_price'
#       5 r = requests.get(url)
# ----> 6 d= r.json()
#       7
#       8 print(d)
#
# ~\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     908                     # used.
#     909                     pass
# --> 910         return complexjson.loads(self.text, **kwargs)
#     911
#     912     @property
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
# ...

# %%
pip install zoopla
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from zoopla import Zoopla

zoopla = Zoopla(api_key='your_api_key')

search = zoopla.property_listings({
    'maximum_beds': 2,
    'page_size': 100,
    'listing_status': 'sale',
    'area': 'Blackley, Greater Manchester'
})

for result in search.listing:
    print(result.price)
    print(result.description)
    print(result.image_url)
# Out:
# C:\Users\prana\anaconda3\lib\site-packages\marshmallow\schema.py:200: ChangedInMarshmallow3Warning: The dateformat option is renamed to datetimeformat in marshmallow 3.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ZooplaAPIException                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22872/132697048.py in <module>
#       3 zoopla = Zoopla(api_key='your_api_key')
#       4
# ----> 5 search = zoopla.property_listings({
#       6     'maximum_beds': 2,
#       7     'page_size': 100,
#
# ~\anaconda3\lib\site-packages\zoopla\api.py in property_listings(self, params)
#     159         Retrieve property listings for a given area.
#     160         """
# --> 161         return self._base_call(
#     162             action='property_listings.json',
#     163             request_schema=SearchPropertyListingRequestSchema,
#
# ...

# %%
https://crimerate.co.uk/berkshire/slough

# %%
# This Wiki sourced dataset is being used to validate the information in the other dataset.
url = 'https://www.ukcrimestats.com/Constituency/65680'
page = requests.get(url)
df_wiki = pd.read_html(url)
df_wiki[0] #Check the correct table from Wiki Page is being picked up
# Out:
#     Unnamed: 0  ASB  Burglary  Robbery  Vehicle  Violent  Shoplifting  CD&A  \
# 0     Jul 2022  193        49       14      129      700           41   122
# 1     Jun 2022  158        56       12       94      612           41   127
# 2     May 2022  184        53       12      127      630           61   133
# 3     Apr 2022  163        41       18      128      534           40   128
# 4     Mar 2022  127        66       12      153      592           39   152
# ..         ...  ...       ...      ...      ...      ...          ...   ...
# 135   Apr 2011  613       118       24      157      213          580   580
# 136   Mar 2011  535       139       25      171      224          585   585
# 137   Feb 2011  514       157       30      141      195          563   563
# 138   Jan 2011  206       180       35      156      210          486   486
# 139   Dec 2010  437       153       36      162      242          479   479
#
# ...
